# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhusaiGandham/Keep-Safe/blob/master/1st_Task(a%2Cb).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from PIL import Image
import requests
# Read and display CSV data
csv_file_path = "/content/diabetes.csv"
df_csv = pd.read_csv(csv_file_path)
print("CSV data:")
print(df_csv)
print()
data = pd.read_csv('/content/diabetes.csv',sep=" ")
print(data)
# Read and display XLS data

xls_file_path = '/content/diabetes.xls'

df_xls = pd.read_excel("/content/diabetes.csv")
print("XLS data:")
print(df_xls)
print()
# Display image
image_path = '/content/rose.jpg'
image = Image.open(image_path)
image.show()

# Read and display web page data
web_page_url = 'https://www.google.com/'
dfs = pd.read_html(web_page_url)

if len(dfs) >0:
    print("Web page data:")
    for df in dfs:
        print(df)
        print()
else:
    print("No tables found on the web page.")
# Out:
# CSV data:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Out:
#    pregnencies  glucose  blood pressure  skin thickness  insuin   BMI  \
# 0            6      148              72              35       0  33.6
# 1            1       53              64              29       0  23.6
# 2            8      141              66               0       0  35.6
# 3            1       89              70              23      94  28.6
# 4            0      153              60              33     168  33.3
#
#    diabetes predict
# 0            0.0627
# 1            0.5341
# 2            0.0672
# 3            0.0167
# 4            2.2880
